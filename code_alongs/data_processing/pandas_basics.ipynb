# %% [markdown]
# ## Pandas basics

# %%
import pandas as pd
df = pd.read_csv("data/banking.csv")
df.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx',
#        'cons_conf_idx', 'euribor3m', 'nr_employed', 'y'],
#       dtype='object')

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp_var_rate    41188 non-null  float64
#  16  cons_price_idx  41188 non-null  float64
# ...

# %%
df["loan"]
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
#         ...
# 41183    yes
# 41184     no
# 41185    yes
# 41186    yes
# 41187     no
# Name: loan, Length: 41188, dtype: object

# %%
df.astype({"loan": "float"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 df.astype({"loan": "float"})
#
# File c:\Users\Kevin\Desktop\Github\Fullstack_data_kevin_kinnunen\.venv\Lib\site-packages\pandas\core\generic.py:6620, in NDFrame.astype(self, dtype, copy, errors)
#    6618 else:
#    6619     try:
# -> 6620         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6621     except ValueError as ex:
#    6622         ex.args = (
#    6623             f"{ex}: Error while type casting for column '{col_name}'",
#    6624         )
#
# File c:\Users\Kevin\Desktop\Github\Fullstack_data_kevin_kinnunen\.venv\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
# ...

# %%
try:
    df.astype({"loan": "float"})
except ValueError as err:
    print(err)
# Out:
# could not convert string to float: 'no': Error while type casting for column 'loan'

# %%
df[pd.to_numeric(df["loan"], errors="coerce").isna()]
# Out:
#        age          job  marital            education  default housing loan  \
# 0       44  blue-collar  married             basic.4y  unknown     yes   no
# 1       53   technician  married              unknown       no      no   no
# 2       28   management   single    university.degree       no     yes   no
# 3       39     services  married          high.school       no      no   no
# 4       55      retired  married             basic.4y       no     yes   no
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   59      retired  married          high.school  unknown      no  yes
# 41184   31    housemaid  married             basic.4y  unknown      no   no
# 41185   42       admin.   single    university.degree  unknown     yes  yes
# 41186   48   technician  married  professional.course       no      no  yes
# 41187   25      student   single          high.school       no      no   no
#
# ...

# %%
df[pd.to_numeric(df["loan"], errors="coerce").notna()]
df.shape
# Out:
# (41188, 21)

# %%
df.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
try:
    df.astype({"loan": "int"})
except ValueError as err:
    print(err)
# Out:
# invalid literal for int() with base 10: 'no': Error while type casting for column 'loan'

# %%
df["loan"] = df["loan"].str.replace('no', "0").str.replace('yes', "1")
df.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes    0
# 1   53   technician  married            unknown       no      no    0
# 2   28   management   single  university.degree       no     yes    0
# 3   39     services  married        high.school       no      no    0
# 4   55      retired  married           basic.4y       no     yes    0
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
df.loan
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41183    1
# 41184    0
# 41185    1
# 41186    1
# 41187    0
# Name: loan, Length: 41188, dtype: object

# %%
# convert loan str val to int
try:
    df.astype({"loan": "int"})
except ValueError as err:
    print(err)
# Out:
# invalid literal for int() with base 10: 'unk0wn': Error while type casting for column 'loan'

# %%
unk0wn_rows = df[df["loan"] == 'unk0wn']

# %%
print(unk0wn_rows)
# Out:
#        age           job  marital            education  default  housing  \
# 90      40   blue-collar  married             basic.9y       no  unknown
# 101     41   blue-collar  married             basic.6y       no  unknown
# 102     37  entrepreneur  married             basic.6y  unknown  unknown
# 157     50    technician  married  professional.course       no  unknown
# 160     50        admin.  married    university.degree       no  unknown
# ...    ...           ...      ...                  ...      ...      ...
# 41004   61       retired  married          high.school       no  unknown
# 41102   34    unemployed  married          high.school       no  unknown
# 41122   39    technician  married             basic.9y  unknown  unknown
# 41132   33        admin.   single    university.degree       no  unknown
# 41158   30      services  married          high.school  unknown  unknown
#
#          loan    contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
# convert loan str val to int and unk0wn to 0 
df["loan"] = df["loan"].str.replace('unk0wn', "0") 
try:
    df.astype({"loan": "int"})
except ValueError as err:
    print(err)

# %%
df = df[df["loan"].notna()]
df.shape
# Out:
# (41188, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp_var_rate    41188 non-null  float64
#  16  cons_price_idx  41188 non-null  float64
# ...

# %%
loan_10_age = df.sort_values(by = "loan", ascending=False).iloc[:10]
loan_10_age[["age", "loan", "marital"]]
# Out:
#        age loan   marital
# 31671   36    1    single
# 31981   31    1   married
# 10742   67    1   married
# 32003   35    1   married
# 31999   55    1  divorced
# 31991   24    1    single
# 10763   26    1    single
# 10767   27    1    single
# 10768   31    1   married
# 10774   53    1   married

# %%
df.plot(x="loan", y="loan_count", kind="scatter")
# Out:
# <Axes: xlabel='loan', ylabel='loan'>
